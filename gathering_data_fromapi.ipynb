# %%
import pandas as pd
import requests

# %%
#response= requests.get('http://www.omdbapi.com/?t=Inception&apikey=17781236&')
#response.json()
# Out:
# {'Title': 'Inception',
#  'Year': '2010',
#  'Rated': 'PG-13',
#  'Released': '16 Jul 2010',
#  'Runtime': '148 min',
#  'Genre': 'Action, Adventure, Sci-Fi',
#  'Director': 'Christopher Nolan',
#  'Writer': 'Christopher Nolan',
#  'Actors': 'Leonardo DiCaprio, Joseph Gordon-Levitt, Elliot Page',
#  'Plot': 'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a C.E.O., but his tragic past may doom the project and his team to disaster.',
#  'Language': 'English, Japanese, French',
#  'Country': 'United States, United Kingdom',
#  'Awards': 'Won 4 Oscars. 159 wins & 220 nominations total',
#  'Poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SX300.jpg',
#  'Ratings': [{'Source': 'Internet Movie Database', 'Value': '8.8/10'},
#   {'Source': 'Rotten Tomatoes', 'Value': '87%'},
#   {'Source': 'Metacritic', 'Value': '74/100'}],
#  'Metascore': '74',
# ...

# %%
response= requests.get('http://www.omdbapi.com/?t=movies&apikey=17781236&')
pd.DataFrame(response.json())
# Out:
#                            Title  Year Rated     Released Runtime  \
# 0  Teen Titans GO! To the Movies  2018    PG  27 Jul 2018  84 min
# 1  Teen Titans GO! To the Movies  2018    PG  27 Jul 2018  84 min
# 2  Teen Titans GO! To the Movies  2018    PG  27 Jul 2018  84 min
#
#                           Genre                           Director  \
# 0  Animation, Action, Adventure  Aaron Horvath, Peter Rida Michail
# 1  Animation, Action, Adventure  Aaron Horvath, Peter Rida Michail
# 2  Animation, Action, Adventure  Aaron Horvath, Peter Rida Michail
#
#                                          Writer  \
# 0  Michael Jelenic, Aaron Horvath, Jerry Siegel
# 1  Michael Jelenic, Aaron Horvath, Jerry Siegel
# 2  Michael Jelenic, Aaron Horvath, Jerry Siegel
#
#                                      Actors  \
# 0  Greg Cipes, Scott Menville, Khary Payton
# 1  Greg Cipes, Scott Menville, Khary Payton
# 2  Greg Cipes, Scott Menville, Khary Payton
#
# ...

# %%
print (response.json())
# Out:
# {'Title': 'Teen Titans GO! To the Movies', 'Year': '2018', 'Rated': 'PG', 'Released': '27 Jul 2018', 'Runtime': '84 min', 'Genre': 'Animation, Action, Adventure', 'Director': 'Aaron Horvath, Peter Rida Michail', 'Writer': 'Michael Jelenic, Aaron Horvath, Jerry Siegel', 'Actors': 'Greg Cipes, Scott Menville, Khary Payton', 'Plot': "A villain's maniacal plan for world domination gets in the way of the Teen Titans' dream of superhero stardom in Hollywood.", 'Language': 'English', 'Country': 'United States', 'Awards': '9 nominations total', 'Poster': 'https://m.media-amazon.com/images/M/MV5BNTU5YjQxNzAtNzkxNC00MGVjLWFhMjgtMjg2ZDUyM2Q5YzdhXkEyXkFqcGc@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '6.7/10'}, {'Source': 'Rotten Tomatoes', 'Value': '92%'}, {'Source': 'Metacritic', 'Value': '69/100'}], 'Metascore': '69', 'imdbRating': '6.7', 'imdbVotes': '23,036', 'imdbID': 'tt7424200', 'Type': 'movie', 'DVD': 'N/A', 'BoxOffice': '$29,790,236', 'Production': 'N/A'
# ...
